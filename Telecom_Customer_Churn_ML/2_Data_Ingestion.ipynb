# %%
df = spark.read.csv("/Volumes/kusha_solutions/telecom_churn_ml/my_volume/customers_data/Telco-Customer-Churn.csv", header=True, inferSchema=True)
df.write.format("delta").saveAsTable("kusha_solutions.telecom_churn_ml.telco_customer_churn")
